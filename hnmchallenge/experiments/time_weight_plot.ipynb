# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

x = np.linspace(0, 4, 101)
plt.plot(x, 1/x, label='$f(x)=1/x$')
plt.legend(loc='upper left')

plt.show()
# Out:
# /tmp/ipykernel_2812085/2299591504.py:8: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(x, 1/x, label='$f(x)=1/x$')

# %%
import seaborn as sns
x = np.linspace(1, 730, 1000)


# plt.rcParams["figure.figsize"] = [20.50, 5.50]
# plt.rcParams["figure.autolayout"] = True
# plt.plot(X, z, color='g', label='09/09-15/09',linewidth=1)
# plt.plot(X, y, color='r', label='16/09-22/09',linewidth=1)

# plt.xlabel("t_dat")
# plt.ylabel("percentage")
# plt.title("articles over time")
# plt.legend()
# plt.show()
fig, ax = plt.subplots()

ax= sns.lineplot(x=x, y=1/pow(x,1/3),label='$f(x)=1/x3$')
ax3= sns.lineplot(x=x, y=1/pow(x,1/2),label='$f(x)=1/x2$')
ax4= sns.lineplot(x=x, y=1/x,label='$f(x)=1/x$')
ax1 = sns.lineplot(x=x, y=(730-x)/730,label='$f(x)=x$')
ax2 = sns.lineplot(x=x, y=1,label='$f(x)=1$')
sns.lineplot(x=x, y=1/(np.exp(-1+x)),label='$f(x)=e$')
plt.axvline(30)
# Out:
# /tmp/ipykernel_2812085/4218470191.py:22: RuntimeWarning: overflow encountered in exp
#   sns.lineplot(x=x, y=1/(np.exp(-1+x)),label='$f(x)=e$')

# %%
from hnmchallenge.matplotlib_utils.setup_plot import setup_plot
#setup_plot(200, fig_ratio=0.5, font_size=8)

fig, ax = plt.subplots()

ax= sns.lineplot(x=x, y=1/pow(x,1/3),label="$f(x)=1/x^{1/3}$")
ax3= sns.lineplot(x=x, y=1/pow(x,1/2),label="$f(x)=1/x^{1/2}$")
ax4= sns.lineplot(x=x, y=1/x,label="$f(x)=1/x$")
ax1 = sns.lineplot(x=x, y=(730-x)/730,label="$f(x)=(730-x)/730$")
ax2 = sns.lineplot(x=x, y=1,label="$f(x)=1$")
sns.lineplot(x=x, y=1/(np.exp(-1+x)),label="$f(x)=1/exp(x-1)$")

#plt.gca().legend(labels=["$f(x)=1/x^{3}$", "_", "$f(x)=1/x^{2}$", "_","$f(x)=1/x$", "_","$f(x)=(730-x)/730$", "_","$f(x)=1$", "_","$f(x)=exp(x-1)$"])
plt.gca().get_legend().get_frame().set_linewidth(0.5)
plt.xlabel("$\Delta~t$")
plt.ylabel("time weight decay value")

plt.tight_layout(pad=0.1, w_pad=0.0, h_pad=0.0)
plt.savefig(
    "time_weight.pdf")
# Out:
# /tmp/ipykernel_2812085/1273236788.py:11: RuntimeWarning: overflow encountered in exp
#   sns.lineplot(x=x, y=1/(np.exp(-1+x)),label="$f(x)=1/exp(x-1)$")

# %%
plt.savefig(
    "time_weight.pdf")
    #bbox_inches="tight",
# Out:
# (None,)
