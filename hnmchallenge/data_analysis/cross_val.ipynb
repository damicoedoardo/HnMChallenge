# %%
import pandas as pd
from hnmchallenge.data_reader import DataReader
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from hnmchallenge.dataset import Dataset
from hnmchallenge.filtered_dataset import FilterdDataset
from hnmchallenge.stratified_dataset import StratifiedDataset
from hnmchallenge.models.top_pop import TopPop
from hnmchallenge.evaluation.python_evaluation import map_at_k, recall_at_k
from hnmchallenge.constant import *
from hnmchallenge.models.sgmc.sgmc import SGMC
from hnmchallenge.models.ease.ease import EASE
from hnmchallenge.models.itemknn.itemknn import ItemKNN 
from hnmchallenge.feature_manager import FeatureManager

# %%
dataset = StratifiedDataset()
dr = DataReader()

# %%
fm = FeatureManager(dataset, "train")

# %%
features_df= pd.read_feather(dr.get_preprocessed_data_path()/ "xgb_datasets" / "dataset_v4.feather")

# %%
import math
TRAIN_PERC = 0.8
VAL_PERC = 0.1
TEST_PERC = 0.1
unique_users = features_df[DEFAULT_USER_COL].unique()
train_len = math.ceil(len(unique_users)*TRAIN_PERC)
val_len =math.ceil(len(unique_users)*VAL_PERC)
test_len =math.ceil(len(unique_users)*TEST_PERC)

np.random.seed(RANDOM_SEED)
np.random.shuffle(unique_users)
train_users, val_users, test_users = unique_users[:train_len], unique_users[train_len:train_len+val_len], unique_users[train_len+val_len:]

# %%
train_df = features_df[features_df[DEFAULT_USER_COL].isin(train_users)]
val_df = features_df[features_df[DEFAULT_USER_COL].isin(val_users)]
test_df = features_df[features_df[DEFAULT_USER_COL].isin(test_users)]

# %%
import xgboost as xgb
# Out:
# /home/aayush/.cache/pypoetry/virtualenvs/hnmchallenge-2TdcNkYi-py3.9/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
model = xgb.XGBRanker(  
    tree_method='gpu_hist',
    booster='gbtree',
    objective='rank:map',
    random_state=RANDOM_SEED, 
    learning_rate=1e-3,
    colsample_bytree=0.9, 
    eta=0.05, 
    max_depth=6, 
    n_estimators=100, 
    subsample=0.75,
    n_gpu = -1,
    )

# %%
X_train = train_df.loc[:, ~train_df.columns.isin([DEFAULT_USER_COL, DEFAULT_ITEM_COL, "relevance"])]
Y_train = train_df["relevance"].copy().values
qid_train = train_df[DEFAULT_USER_COL].copy().values

X_val = val_df.loc[:, ~val_df.columns.isin([DEFAULT_USER_COL, DEFAULT_ITEM_COL, "relevance"])]
Y_val = val_df["relevance"].copy().values
qid_val = val_df[DEFAULT_USER_COL].copy().values

X_test = test_df.loc[:, ~test_df.columns.isin([DEFAULT_USER_COL, DEFAULT_ITEM_COL, "relevance"])]
Y_test = test_df["relevance"].copy().values
qid_test = test_df[DEFAULT_USER_COL].copy().values

# %%
X=pd.unique(train_df[DEFAULT_USER_COL])

# %%
X
# Out:
# array([     29,     129,     136, ..., 1128600, 1128602, 1128611])

# %%
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10, shuffle=True, random_state=1)

# %%
score=[]
tree=[]
for train_user,test_user in kfold.split(features_df):
    train_df = features_df[features_df[DEFAULT_USER_COL].isin(train_user)]
    test_df = features_df[features_df[DEFAULT_USER_COL].isin(test_user)]

    X_train = train_df.loc[:, ~train_df.columns.isin([DEFAULT_USER_COL, DEFAULT_ITEM_COL, "relevance"])]
    Y_train = train_df["relevance"].copy().values
    qid_train = train_df[DEFAULT_USER_COL].copy().values

    X_test = test_df.loc[:, ~test_df.columns.isin([DEFAULT_USER_COL, DEFAULT_ITEM_COL, "relevance"])]
    Y_test = test_df["relevance"].copy().values
    qid_test = test_df[DEFAULT_USER_COL].copy().values  
    
    model.fit(X_train, Y_train, qid=qid_train, eval_set=[(X_test, Y_test)], eval_qid=[qid_test], eval_metric=["map@12"],
          verbose=True,  early_stopping_rounds=20)

    tree.append(model.best_ntree_limit)
    score.append(model.best_score)
# Out:
# /home/aayush/.cache/pypoetry/virtualenvs/hnmchallenge-2TdcNkYi-py3.9/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [20:36:34] WARNING: ../src/learner.cc:576:
# Parameters: { "n_gpu" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-map@12:0.20345
# [1]	validation_0-map@12:0.20434
# [2]	validation_0-map@12:0.21022
# [3]	validation_0-map@12:0.20832
# [4]	validation_0-map@12:0.20794
# [5]	validation_0-map@12:0.21070
# [6]	validation_0-map@12:0.21135
# [7]	validation_0-map@12:0.20963
# [8]	validation_0-map@12:0.21166
# [9]	validation_0-map@12:0.21082
# [10]	validation_0-map@12:0.20971
# [11]	validation_0-map@12:0.20995
# [12]	validation_0-map@12:0.21015
# [13]	validation_0-map@12:0.20917
# [14]	validation_0-map@12:0.20836
# [15]	validation_0-map@12:0.20858
# [16]	validation_0-map@12:0.20962
# [17]	validation_0-map@12:0.21007
# [18]	validation_0-map@12:0.21052
# [19]	validation_0-map@12:0.20997
# [20]	validation_0-map@12:0.20981
# [21]	validation_0-map@12:0.20961
# [22]	validation_0-map@12:0.20923
# [23]	validation_0-map@12:0.20990
# [24]	validation_0-map@12:0.20959
# [25]	validation_0-map@12:0.21039
# [26]	validation_0-map@12:0.21039
# [27]	validation_0-map@12:0.21399
# [28]	validation_0-map@12:0.21415
# [29]	validation_0-map@12:0.21439
# [30]	validation_0-map@12:0.21339
# [31]	validation_0-map@12:0.21250
# [32]	validation_0-map@12:0.21234
# [33]	validation_0-map@12:0.21305
# [34]	validation_0-map@12:0.21324
# [35]	validation_0-map@12:0.21367
# [36]	validation_0-map@12:0.21382
# [37]	validation_0-map@12:0.21357
# [38]	validation_0-map@12:0.21340
# [39]	validation_0-map@12:0.21387
# [40]	validation_0-map@12:0.21366
# [41]	validation_0-map@12:0.21391
# [42]	validation_0-map@12:0.21443
# [43]	validation_0-map@12:0.21480
# [44]	validation_0-map@12:0.21432
# [45]	validation_0-map@12:0.21580
# [46]	validation_0-map@12:0.21524
# [47]	validation_0-map@12:0.21489
# [48]	validation_0-map@12:0.21526
# [49]	validation_0-map@12:0.21518
# [50]	validation_0-map@12:0.21557
# [51]	validation_0-map@12:0.21623
# [52]	validation_0-map@12:0.21647
# [53]	validation_0-map@12:0.21634
# [54]	validation_0-map@12:0.21613
# [55]	validation_0-map@12:0.21721
# [56]	validation_0-map@12:0.21816
# [57]	validation_0-map@12:0.21766
# [58]	validation_0-map@12:0.21698
# [59]	validation_0-map@12:0.21716
# [60]	validation_0-map@12:0.21735
# [61]	validation_0-map@12:0.21754
# [62]	validation_0-map@12:0.21757
# [63]	validation_0-map@12:0.21786
# [64]	validation_0-map@12:0.21752
# [65]	validation_0-map@12:0.21705
# [66]	validation_0-map@12:0.21744
# [67]	validation_0-map@12:0.21760
# [68]	validation_0-map@12:0.21706
# [69]	validation_0-map@12:0.21729
# [70]	validation_0-map@12:0.21724
# [71]	validation_0-map@12:0.21730
# [72]	validation_0-map@12:0.21780
# [73]	validation_0-map@12:0.21790
# [74]	validation_0-map@12:0.21827
# [75]	validation_0-map@12:0.21803
# [76]	validation_0-map@12:0.21826
# [77]	validation_0-map@12:0.21793
# [78]	validation_0-map@12:0.21759
# [79]	validation_0-map@12:0.21757
# [80]	validation_0-map@12:0.21713
# [81]	validation_0-map@12:0.21739
# [82]	validation_0-map@12:0.21719
# [83]	validation_0-map@12:0.21738
# [84]	validation_0-map@12:0.21727
# [85]	validation_0-map@12:0.21722
# [86]	validation_0-map@12:0.21723
# [87]	validation_0-map@12:0.21718
# [88]	validation_0-map@12:0.21794
# [89]	validation_0-map@12:0.21774
# [90]	validation_0-map@12:0.21779
# [91]	validation_0-map@12:0.21731
# [92]	validation_0-map@12:0.21762
# [93]	validation_0-map@12:0.21751
# [94]	validation_0-map@12:0.21817
# [20:36:37] WARNING: ../src/learner.cc:576:
# Parameters: { "n_gpu" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-map@12:0.21396
# [1]	validation_0-map@12:0.21213
# [2]	validation_0-map@12:0.21602
# [3]	validation_0-map@12:0.21413
# [4]	validation_0-map@12:0.21524
# [5]	validation_0-map@12:0.21799
# [6]	validation_0-map@12:0.21765
# [7]	validation_0-map@12:0.21758
# [8]	validation_0-map@12:0.21860
# [9]	validation_0-map@12:0.21871
# [10]	validation_0-map@12:0.21926
# [11]	validation_0-map@12:0.22130
# [12]	validation_0-map@12:0.22251
# [13]	validation_0-map@12:0.22206
# [14]	validation_0-map@12:0.21976
# [15]	validation_0-map@12:0.22070
# [16]	validation_0-map@12:0.22136
# [17]	validation_0-map@12:0.21960
# [18]	validation_0-map@12:0.22121
# [19]	validation_0-map@12:0.22125
# [20]	validation_0-map@12:0.22021
# [21]	validation_0-map@12:0.22038
# [22]	validation_0-map@12:0.22078
# [23]	validation_0-map@12:0.22152
# [24]	validation_0-map@12:0.22097
# [25]	validation_0-map@12:0.22123
# [26]	validation_0-map@12:0.22158
# [27]	validation_0-map@12:0.22419
# [28]	validation_0-map@12:0.22474
# [29]	validation_0-map@12:0.22513
# [30]	validation_0-map@12:0.22537
# [31]	validation_0-map@12:0.22528
# [32]	validation_0-map@12:0.22504
# [33]	validation_0-map@12:0.22482
# [34]	validation_0-map@12:0.22499
# [35]	validation_0-map@12:0.22487
# [36]	validation_0-map@12:0.22508
# [37]	validation_0-map@12:0.22498
# [38]	validation_0-map@12:0.22580
# [39]	validation_0-map@12:0.22608
# [40]	validation_0-map@12:0.22557
# [41]	validation_0-map@12:0.22529
# [42]	validation_0-map@12:0.22553
# [43]	validation_0-map@12:0.22629
# [44]	validation_0-map@12:0.22569
# [45]	validation_0-map@12:0.22635
# [46]	validation_0-map@12:0.22678
# [47]	validation_0-map@12:0.22665
# [48]	validation_0-map@12:0.22730
# [49]	validation_0-map@12:0.22686
# [50]	validation_0-map@12:0.22695
# [51]	validation_0-map@12:0.22674
# [52]	validation_0-map@12:0.22692
# [53]	validation_0-map@12:0.22653
# [54]	validation_0-map@12:0.22722
# [55]	validation_0-map@12:0.22714
# [56]	validation_0-map@12:0.22704
# [57]	validation_0-map@12:0.22726
# [58]	validation_0-map@12:0.22703
# [59]	validation_0-map@12:0.22707
# [60]	validation_0-map@12:0.22710
# [61]	validation_0-map@12:0.22725
# [62]	validation_0-map@12:0.22734
# [63]	validation_0-map@12:0.22701
# [64]	validation_0-map@12:0.22711
# [65]	validation_0-map@12:0.22691
# [66]	validation_0-map@12:0.22687
# [67]	validation_0-map@12:0.22708
# [68]	validation_0-map@12:0.22727
# [69]	validation_0-map@12:0.22779
# [70]	validation_0-map@12:0.22846
# [71]	validation_0-map@12:0.22839
# [72]	validation_0-map@12:0.22871
# [73]	validation_0-map@12:0.22811
# [74]	validation_0-map@12:0.22911
# [75]	validation_0-map@12:0.22870
# [76]	validation_0-map@12:0.22883
# [77]	validation_0-map@12:0.22830
# [78]	validation_0-map@12:0.22855
# [79]	validation_0-map@12:0.22803
# [80]	validation_0-map@12:0.22867
# [81]	validation_0-map@12:0.22855
# [82]	validation_0-map@12:0.22857
# [83]	validation_0-map@12:0.22869
# [84]	validation_0-map@12:0.22875
# [85]	validation_0-map@12:0.22885
# [86]	validation_0-map@12:0.22883
# [87]	validation_0-map@12:0.22871
# [88]	validation_0-map@12:0.22836
# [89]	validation_0-map@12:0.22858
# [90]	validation_0-map@12:0.22868
# [91]	validation_0-map@12:0.22809
# [92]	validation_0-map@12:0.22843
# [93]	validation_0-map@12:0.22826
# [94]	validation_0-map@12:0.22770
# [20:36:39] WARNING: ../src/learner.cc:576:
# Parameters: { "n_gpu" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-map@12:0.20445
# [1]	validation_0-map@12:0.20043
# [2]	validation_0-map@12:0.20536
# [3]	validation_0-map@12:0.20112
# [4]	validation_0-map@12:0.20227
# [5]	validation_0-map@12:0.20266
# [6]	validation_0-map@12:0.20567
# [7]	validation_0-map@12:0.20348
# [8]	validation_0-map@12:0.20499
# [9]	validation_0-map@12:0.20609
# [10]	validation_0-map@12:0.20689
# [11]	validation_0-map@12:0.20723
# [12]	validation_0-map@12:0.20649
# [13]	validation_0-map@12:0.20518
# [14]	validation_0-map@12:0.20513
# [15]	validation_0-map@12:0.20598
# [16]	validation_0-map@12:0.20647
# [17]	validation_0-map@12:0.20694
# [18]	validation_0-map@12:0.20704
# [19]	validation_0-map@12:0.20680
# [20]	validation_0-map@12:0.20558
# [21]	validation_0-map@12:0.20607
# [22]	validation_0-map@12:0.20570
# [23]	validation_0-map@12:0.20691
# [24]	validation_0-map@12:0.20639
# [25]	validation_0-map@12:0.20660
# [26]	validation_0-map@12:0.20713
# [27]	validation_0-map@12:0.20658
# [28]	validation_0-map@12:0.20739
# [29]	validation_0-map@12:0.20768
# [30]	validation_0-map@12:0.20664
# [31]	validation_0-map@12:0.20757
# [32]	validation_0-map@12:0.20724
# [33]	validation_0-map@12:0.20709
# [34]	validation_0-map@12:0.20727
# [35]	validation_0-map@12:0.20666
# [36]	validation_0-map@12:0.20723
# [37]	validation_0-map@12:0.20677
# [38]	validation_0-map@12:0.20664
# [39]	validation_0-map@12:0.20580
# [40]	validation_0-map@12:0.20594
# [41]	validation_0-map@12:0.20603
# [42]	validation_0-map@12:0.20571
# [43]	validation_0-map@12:0.20589
# [44]	validation_0-map@12:0.20607
# [45]	validation_0-map@12:0.20639
# [46]	validation_0-map@12:0.20670
# [47]	validation_0-map@12:0.20658
# [48]	validation_0-map@12:0.20639
# [49]	validation_0-map@12:0.20658
# [20:36:41] WARNING: ../src/learner.cc:576:
# Parameters: { "n_gpu" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-map@12:0.19966
# [1]	validation_0-map@12:0.19862
# [2]	validation_0-map@12:0.20214
# [3]	validation_0-map@12:0.19981
# [4]	validation_0-map@12:0.20127
# [5]	validation_0-map@12:0.20553
# [6]	validation_0-map@12:0.20689
# [7]	validation_0-map@12:0.20373
# [8]	validation_0-map@12:0.20418
# [9]	validation_0-map@12:0.20597
# [10]	validation_0-map@12:0.20580
# [11]	validation_0-map@12:0.20681
# [12]	validation_0-map@12:0.20699
# [13]	validation_0-map@12:0.20659
# [14]	validation_0-map@12:0.20630
# [15]	validation_0-map@12:0.20681
# [16]	validation_0-map@12:0.20689
# [17]	validation_0-map@12:0.20750
# [18]	validation_0-map@12:0.20741
# [19]	validation_0-map@12:0.20705
# [20]	validation_0-map@12:0.20768
# [21]	validation_0-map@12:0.20828
# [22]	validation_0-map@12:0.20864
# [23]	validation_0-map@12:0.20903
# [24]	validation_0-map@12:0.20841
# [25]	validation_0-map@12:0.20823
# [26]	validation_0-map@12:0.20884
# [27]	validation_0-map@12:0.21273
# [28]	validation_0-map@12:0.21296
# [29]	validation_0-map@12:0.21274
# [30]	validation_0-map@12:0.21355
# [31]	validation_0-map@12:0.21298
# [32]	validation_0-map@12:0.21345
# [33]	validation_0-map@12:0.21310
# [34]	validation_0-map@12:0.21223
# [35]	validation_0-map@12:0.21200
# [36]	validation_0-map@12:0.21245
# [37]	validation_0-map@12:0.21386
# [38]	validation_0-map@12:0.21389
# [39]	validation_0-map@12:0.21393
# [40]	validation_0-map@12:0.21430
# [41]	validation_0-map@12:0.21445
# [42]	validation_0-map@12:0.21402
# [43]	validation_0-map@12:0.21366
# [44]	validation_0-map@12:0.21352
# [45]	validation_0-map@12:0.21528
# [46]	validation_0-map@12:0.21566
# [47]	validation_0-map@12:0.21537
# [48]	validation_0-map@12:0.21459
# [49]	validation_0-map@12:0.21503
# [50]	validation_0-map@12:0.21510
# [51]	validation_0-map@12:0.21542
# [52]	validation_0-map@12:0.21613
# [53]	validation_0-map@12:0.21503
# [54]	validation_0-map@12:0.21480
# [55]	validation_0-map@12:0.21624
# [56]	validation_0-map@12:0.21599
# [57]	validation_0-map@12:0.21523
# [58]	validation_0-map@12:0.21535
# [59]	validation_0-map@12:0.21582
# [60]	validation_0-map@12:0.21535
# [61]	validation_0-map@12:0.21549
# [62]	validation_0-map@12:0.21544
# [63]	validation_0-map@12:0.21527
# [64]	validation_0-map@12:0.21490
# [65]	validation_0-map@12:0.21509
# [66]	validation_0-map@12:0.21480
# [67]	validation_0-map@12:0.21481
# [68]	validation_0-map@12:0.21515
# [69]	validation_0-map@12:0.21482
# [70]	validation_0-map@12:0.21478
# [71]	validation_0-map@12:0.21566
# [72]	validation_0-map@12:0.21501
# [73]	validation_0-map@12:0.21523
# [74]	validation_0-map@12:0.21570
# [75]	validation_0-map@12:0.21553
# [20:36:43] WARNING: ../src/learner.cc:576:
# Parameters: { "n_gpu" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-map@12:0.20023
# [1]	validation_0-map@12:0.19837
# [2]	validation_0-map@12:0.20489
# [3]	validation_0-map@12:0.20447
# [4]	validation_0-map@12:0.20466
# [5]	validation_0-map@12:0.20718
# [6]	validation_0-map@12:0.20952
# [7]	validation_0-map@12:0.20713
# [8]	validation_0-map@12:0.20816
# [9]	validation_0-map@12:0.20774
# [10]	validation_0-map@12:0.20850
# [16]	validation_0-map@12:0.21808
# [17]	validation_0-map@12:0.21924
# [18]	validation_0-map@12:0.21863
# [19]	validation_0-map@12:0.21775
# [20]	validation_0-map@12:0.21768
# [21]	validation_0-map@12:0.21734
# [22]	validation_0-map@12:0.21802
# [23]	validation_0-map@12:0.21851
# [24]	validation_0-map@12:0.21892
# [25]	validation_0-map@12:0.21932
# [26]	validation_0-map@12:0.21942
# [27]	validation_0-map@12:0.21949
# [28]	validation_0-map@12:0.22031
# [29]	validation_0-map@12:0.22000
# [30]	validation_0-map@12:0.22133
# [31]	validation_0-map@12:0.21943
# [32]	validation_0-map@12:0.21984
# [33]	validation_0-map@12:0.21988
# [34]	validation_0-map@12:0.22048
# [35]	validation_0-map@12:0.22085
# [36]	validation_0-map@12:0.22142
# [37]	validation_0-map@12:0.22144
# [38]	validation_0-map@12:0.22137
# [39]	validation_0-map@12:0.22140
# [40]	validation_0-map@12:0.22187
# [41]	validation_0-map@12:0.22208
# [42]	validation_0-map@12:0.22182
# [43]	validation_0-map@12:0.22220
# [44]	validation_0-map@12:0.22196
# [45]	validation_0-map@12:0.22046
# [46]	validation_0-map@12:0.22067
# [47]	validation_0-map@12:0.22083
# [48]	validation_0-map@12:0.22078
# [49]	validation_0-map@12:0.22089
# [50]	validation_0-map@12:0.22172
# [51]	validation_0-map@12:0.22142
# [52]	validation_0-map@12:0.22172
# [53]	validation_0-map@12:0.22187
# [54]	validation_0-map@12:0.22182
# [55]	validation_0-map@12:0.22203
# [56]	validation_0-map@12:0.22184
# [57]	validation_0-map@12:0.22278
# [58]	validation_0-map@12:0.22234
# [59]	validation_0-map@12:0.22213
# [60]	validation_0-map@12:0.22233
# [61]	validation_0-map@12:0.22304
# [62]	validation_0-map@12:0.22320
# [63]	validation_0-map@12:0.22343
# [64]	validation_0-map@12:0.22375
# [65]	validation_0-map@12:0.22375
# [66]	validation_0-map@12:0.22429
# [67]	validation_0-map@12:0.22351
# [68]	validation_0-map@12:0.22343
# [69]	validation_0-map@12:0.22305
# [70]	validation_0-map@12:0.22314
# [71]	validation_0-map@12:0.22243
# [72]	validation_0-map@12:0.22254
# [73]	validation_0-map@12:0.22264
# [74]	validation_0-map@12:0.22279
# [75]	validation_0-map@12:0.22287
# [76]	validation_0-map@12:0.22298
# [77]	validation_0-map@12:0.22291
# [78]	validation_0-map@12:0.22292
# [79]	validation_0-map@12:0.22293
# [80]	validation_0-map@12:0.22292
# [81]	validation_0-map@12:0.22296
# [82]	validation_0-map@12:0.22301
# [83]	validation_0-map@12:0.22297
# [84]	validation_0-map@12:0.22305
# [85]	validation_0-map@12:0.22296
# [20:36:50] WARNING: ../src/learner.cc:576:
# Parameters: { "n_gpu" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-map@12:0.20430
# [1]	validation_0-map@12:0.19779
# [2]	validation_0-map@12:0.20256
# [3]	validation_0-map@12:0.19967
# [4]	validation_0-map@12:0.20319
# [5]	validation_0-map@12:0.20576
# [6]	validation_0-map@12:0.20600
# [7]	validation_0-map@12:0.20554
# [8]	validation_0-map@12:0.20544
# [9]	validation_0-map@12:0.20617
# [10]	validation_0-map@12:0.20677
# [11]	validation_0-map@12:0.20786
# [12]	validation_0-map@12:0.20786
# [13]	validation_0-map@12:0.20773
# [14]	validation_0-map@12:0.20720
# [15]	validation_0-map@12:0.20874
# [16]	validation_0-map@12:0.20844
# [17]	validation_0-map@12:0.20874
# [18]	validation_0-map@12:0.20829
# [19]	validation_0-map@12:0.20783
# [20]	validation_0-map@12:0.20770
# [21]	validation_0-map@12:0.20848
# [22]	validation_0-map@12:0.20958
# [23]	validation_0-map@12:0.20949
# [24]	validation_0-map@12:0.20826
# [25]	validation_0-map@12:0.20884
# [26]	validation_0-map@12:0.20911
# [27]	validation_0-map@12:0.20952
# [28]	validation_0-map@12:0.20979
# [29]	validation_0-map@12:0.21064
# [30]	validation_0-map@12:0.21071
# [31]	validation_0-map@12:0.21091
# [32]	validation_0-map@12:0.21106
# [33]	validation_0-map@12:0.21086
# [34]	validation_0-map@12:0.21146
# [35]	validation_0-map@12:0.21141
# [36]	validation_0-map@12:0.21124
# [37]	validation_0-map@12:0.21061
# [38]	validation_0-map@12:0.21111
# [39]	validation_0-map@12:0.21123
# [40]	validation_0-map@12:0.21150
# [41]	validation_0-map@12:0.21157
# [42]	validation_0-map@12:0.21167
# [43]	validation_0-map@12:0.21218
# [44]	validation_0-map@12:0.21210
# [45]	validation_0-map@12:0.21272
# [46]	validation_0-map@12:0.21326
# [47]	validation_0-map@12:0.21322
# [48]	validation_0-map@12:0.21355
# [49]	validation_0-map@12:0.21326
# [50]	validation_0-map@12:0.21513
# [51]	validation_0-map@12:0.21492
# [52]	validation_0-map@12:0.21490
# [53]	validation_0-map@12:0.21457
# [54]	validation_0-map@12:0.21435
# [55]	validation_0-map@12:0.21437
# [56]	validation_0-map@12:0.21405
# [57]	validation_0-map@12:0.21424
# [58]	validation_0-map@12:0.21407
# [59]	validation_0-map@12:0.21414
# [60]	validation_0-map@12:0.21434
# [61]	validation_0-map@12:0.21438
# [62]	validation_0-map@12:0.21408
# [63]	validation_0-map@12:0.21408
# [64]	validation_0-map@12:0.21410
# [65]	validation_0-map@12:0.21443
# [66]	validation_0-map@12:0.21452
# [67]	validation_0-map@12:0.21481
# [68]	validation_0-map@12:0.21459
# [69]	validation_0-map@12:0.21438
# [70]	validation_0-map@12:0.21465
# [20:36:52] WARNING: ../src/learner.cc:576:
# Parameters: { "n_gpu" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-map@12:0.21366
# [1]	validation_0-map@12:0.21403
# [2]	validation_0-map@12:0.21813
# [3]	validation_0-map@12:0.21659
# [4]	validation_0-map@12:0.21731
# [5]	validation_0-map@12:0.21921
# [6]	validation_0-map@12:0.22010
# [7]	validation_0-map@12:0.22008
# [8]	validation_0-map@12:0.22129
# [9]	validation_0-map@12:0.22187
# [10]	validation_0-map@12:0.22097
# [11]	validation_0-map@12:0.22096
# [12]	validation_0-map@12:0.22129
# [13]	validation_0-map@12:0.22112
# [14]	validation_0-map@12:0.21993
# [15]	validation_0-map@12:0.22109
# [16]	validation_0-map@12:0.22150
# [17]	validation_0-map@12:0.22157
# [18]	validation_0-map@12:0.22118
# [19]	validation_0-map@12:0.22172
# [20]	validation_0-map@12:0.22097
# [21]	validation_0-map@12:0.22130
# [22]	validation_0-map@12:0.22094
# [23]	validation_0-map@12:0.22196
# [24]	validation_0-map@12:0.22116
# [25]	validation_0-map@12:0.22100
# [26]	validation_0-map@12:0.22102
# [27]	validation_0-map@12:0.22359
# [28]	validation_0-map@12:0.22351
# [29]	validation_0-map@12:0.22458
# [30]	validation_0-map@12:0.22436
# [31]	validation_0-map@12:0.22493
# [32]	validation_0-map@12:0.22464
# [33]	validation_0-map@12:0.22399
# [34]	validation_0-map@12:0.22309
# [35]	validation_0-map@12:0.22271
# [36]	validation_0-map@12:0.22356
# [37]	validation_0-map@12:0.22376
# [38]	validation_0-map@12:0.22382
# [39]	validation_0-map@12:0.22417
# [40]	validation_0-map@12:0.22450
# [41]	validation_0-map@12:0.22440
# [42]	validation_0-map@12:0.22494
# [43]	validation_0-map@12:0.22478
# [44]	validation_0-map@12:0.22453
# [45]	validation_0-map@12:0.22633
# [46]	validation_0-map@12:0.22634
# [47]	validation_0-map@12:0.22639
# [48]	validation_0-map@12:0.22595
# [49]	validation_0-map@12:0.22573
# [50]	validation_0-map@12:0.22554
# [51]	validation_0-map@12:0.22570
# [52]	validation_0-map@12:0.22615
# [53]	validation_0-map@12:0.22616
# [54]	validation_0-map@12:0.22585
# [55]	validation_0-map@12:0.22662
# [56]	validation_0-map@12:0.22731
# [57]	validation_0-map@12:0.22752
# [58]	validation_0-map@12:0.22718
# [59]	validation_0-map@12:0.22665
# [60]	validation_0-map@12:0.22672
# [61]	validation_0-map@12:0.22684
# [62]	validation_0-map@12:0.22673
# [63]	validation_0-map@12:0.22569
# [64]	validation_0-map@12:0.22584
# [65]	validation_0-map@12:0.22555
# [66]	validation_0-map@12:0.22559
# [67]	validation_0-map@12:0.22577
# [68]	validation_0-map@12:0.22595
# [69]	validation_0-map@12:0.22560
# [70]	validation_0-map@12:0.22564
# [71]	validation_0-map@12:0.22514
# [72]	validation_0-map@12:0.22482
# [73]	validation_0-map@12:0.22456
# [74]	validation_0-map@12:0.22476
# [75]	validation_0-map@12:0.22465
# [76]	validation_0-map@12:0.22496
# [77]	validation_0-map@12:0.22540
# [20:36:54] WARNING: ../src/learner.cc:576:
# Parameters: { "n_gpu" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-map@12:0.20437
# [1]	validation_0-map@12:0.20110
# [2]	validation_0-map@12:0.20906
# [3]	validation_0-map@12:0.20773
# [4]	validation_0-map@12:0.21008
# [5]	validation_0-map@12:0.21236
# [6]	validation_0-map@12:0.21514
# [7]	validation_0-map@12:0.21331
# [8]	validation_0-map@12:0.21372
# [9]	validation_0-map@12:0.21433
# [10]	validation_0-map@12:0.21469
# [11]	validation_0-map@12:0.21471
# [12]	validation_0-map@12:0.21441
# [13]	validation_0-map@12:0.21343
# [14]	validation_0-map@12:0.21356
# [15]	validation_0-map@12:0.21324
# [16]	validation_0-map@12:0.21406
# [17]	validation_0-map@12:0.21410
# [18]	validation_0-map@12:0.21361
# [19]	validation_0-map@12:0.21335
# [20]	validation_0-map@12:0.21287
# [21]	validation_0-map@12:0.21410
# [22]	validation_0-map@12:0.21447
# [23]	validation_0-map@12:0.21495
# [24]	validation_0-map@12:0.21445
# [25]	validation_0-map@12:0.21428
# [26]	validation_0-map@12:0.21505

# %%
score
# Out:
# [0.218268,
#  0.229106,
#  0.207683,
#  0.216236,
#  0.219044,
#  0.212351,
#  0.224286,
#  0.215131,
#  0.22752,
#  0.215142]

# %%
tree
# Out:
# [75, 75, 30, 56, 54, 72, 67, 51, 58, 7]
